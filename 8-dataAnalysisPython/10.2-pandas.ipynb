# %% [markdown]
# #### Pandas-DataFrame And Series
# Pandas is a powerful data manipulation library in Python, widely used for data analysis and data cleaning. It provides two primary data structures: Series and DataFrame. A Series is a one-dimensional array-like object, while a DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns).

# %%
# %pip install -U pandas numpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 841.6 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 16.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 11.5 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 11.9 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip3.12 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
## Series
##A Pandas Series is a one-dimensional array-like object that can hold any data type. It is similar to a column in a table.

import pandas as pd
data=[1,2,3,4,5]
series=pd.Series(data)
print("Series \n",series)
print(type(series))
# Out:
# Series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
## Create a Series from dictionary
data={'a':1,'b':2,'c':3}
series_dict=pd.Series(data)
print(series_dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data=[10,20,30]
index=['a','b','c']
pd.Series(data,index=index) # .Series is a class in pandas module which is used to create a Series object
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
## Dataframe
## create a Dataframe from a dictionary oof list
# DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns).
data={
    'Name':['Krish','John','Jack'],
    'Age':[25,30,45],
    'City':['Bangalore','New York','Florida']
}
df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New York
# 2   Jack   45    Florida
# <class 'pandas.core.frame.DataFrame'>

# %%
## Create a Data frame From a List of Dictionaries

data=[
    {'Name':'Krish','Age':32,'City':'Bangalore'},
    {'Name':'John','Age':34,'City':'Bangalore'},
    {'Name':'Bappy','Age':32,'City':'Bangalore'},
    {'Name':'JAck','Age':32,'City':'Bangalore'}
    
]
df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Name  Age       City
# 0  Krish   32  Bangalore
# 1   John   34  Bangalore
# 2  Bappy   32  Bangalore
# 3   JAck   32  Bangalore
# <class 'pandas.core.frame.DataFrame'>

# %%
df=pd.read_csv('online_sales_dataset.csv')
df.head(10)
# Out:
#    InvoiceNo StockCode     Description  Quantity       InvoiceDate  UnitPrice  \
# 0     221958  SKU_1964       White Mug        38  2020-01-01 00:00       1.71
# 1     771155  SKU_1241       White Mug        18  2020-01-01 01:00      41.25
# 2     231932  SKU_1501      Headphones        49  2020-01-01 02:00      29.11
# 3     465838  SKU_1760       Desk Lamp        14  2020-01-01 03:00      76.68
# 4     359178  SKU_1386       USB Cable       -30  2020-01-01 04:00     -68.11
# 5     744167  SKU_1006    Office Chair        47  2020-01-01 05:00      70.16
# 6     210268  SKU_1087       USB Cable        25  2020-01-01 06:00      85.74
# 7     832180  SKU_1597        Notebook         8  2020-01-01 07:00      95.65
# 8     154886  SKU_1907  Wireless Mouse        19  2020-01-01 08:00      98.19
# 9     237337  SKU_1866      Headphones        40  2020-01-01 09:00      98.17
#
#    CustomerID         Country  Discount  PaymentMethod  ShippingCost  \
# ...

# %%
df.tail(20)
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 49762     691338  SKU_1543    Wall Clock        19  2025-09-04 10:00
# 49763     115451  SKU_1660  Office Chair        21  2025-09-04 11:00
# 49764     465384  SKU_1165      Blue Pen        28  2025-09-04 12:00
# 49765     414230  SKU_1409    Wall Clock        18  2025-09-04 13:00
# 49766     148393  SKU_1296     USB Cable        10  2025-09-04 14:00
# 49767     748751  SKU_1688     Desk Lamp        43  2025-09-04 15:00
# 49768     575634  SKU_1852      Blue Pen        37  2025-09-04 16:00
# 49769     701257  SKU_1092  Office Chair        19  2025-09-04 17:00
# 49770     625657  SKU_1628  Office Chair       -30  2025-09-04 18:00
# 49771     376212  SKU_1936      Notebook         1  2025-09-04 19:00
# 49772     224131  SKU_1095     USB Cable        27  2025-09-04 20:00
# 49773     370260  SKU_1570      Blue Pen        12  2025-09-04 21:00
# 49774     274759  SKU_1899     USB Cable        43  2025-09-04 22:00
# ...

# %%
### Accessing Data From Dataframe
df
# Out:
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New York
# 2   Jack   45    Florida

# %%
df['Name']
# Out:
# 0    Krish
# 1     John
# 2     Jack
# Name: Name, dtype: object

# %%
df.loc[0] # Access the first row of the DataFrame
# Out:
# Name        Krish
# Age            25
# City    Bangalore
# Name: 0, dtype: object

# %%
df.iloc[0] # column based access
# Out:
# Name        Krish
# Age            25
# City    Bangalore
# Name: 0, dtype: object

# %%
df
# Out:
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New York
# 2   Jack   45    Florida

# %%
## Accessing a specified element
df.at[2,'Age']
# Out:
# 45

# %%
df.at[2,'Name']
# Out:
# 'Jack'

# %%
## Accessing a specified element using iat
df.iat[2,2]
# Out:
# 'Florida'

# %%
df
# Out:
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New York
# 2   Jack   45    Florida

# %%
### Data MAnipulation with Dataframe
df
# Out:
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New York
# 2   Jack   45    Florida

# %%
## Adding a column
df['Salary']=[50000,60000,70000]
df
# Out:
#     Name  Age       City  Salary
# 0  Krish   25  Bangalore   50000
# 1   John   30   New York   60000
# 2   Jack   45    Florida   70000

# %%
## Remove a column
df.drop('Salary',axis=1,inplace=True)  # axis has two values 0 for row and 1 for column

# %%
df
# Out:
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New York
# 2   Jack   45    Florida

# %%
## Add age to the column
df['Age']=df['Age']+1
df
# Out:
#     Name  Age       City
# 0  Krish   26  Bangalore
# 1   John   31   New York
# 2   Jack   46    Florida

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#    Name  Age      City
# 1  John   31  New York
# 2  Jack   46   Florida

# %%
df=pd.read_csv('sales_data.csv')
df.head(5)
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
# Display the data types of each column
print("Data types:\n", df.dtypes)

# Describe the DataFrame
print("Statistical summary:\n", df.describe())
# Out:
# Data types:
#  Transaction ID        int64
# Date                 object
# Product Category     object
# Product Name         object
# Units Sold            int64
# Unit Price          float64
# Total Revenue       float64
# Region               object
# Payment Method       object
# dtype: object
# Statistical summary:
#         Transaction ID  Units Sold   Unit Price  Total Revenue
# count       240.00000  240.000000   240.000000     240.000000
# mean      10120.50000    2.158333   236.395583     335.699375
# std          69.42622    1.322454   429.446695     485.804469
# min       10001.00000    1.000000     6.500000       6.500000
# 25%       10060.75000    1.000000    29.500000      62.965000
# 50%       10120.50000    2.000000    89.990000     179.970000
# 75%       10180.25000    3.000000   249.990000     399.225000
# max       10240.00000   10.000000  3899.990000    3899.990000

# %%
df.describe()
# Out:
#        Transaction ID  Units Sold   Unit Price  Total Revenue
# count       240.00000  240.000000   240.000000     240.000000
# mean      10120.50000    2.158333   236.395583     335.699375
# std          69.42622    1.322454   429.446695     485.804469
# min       10001.00000    1.000000     6.500000       6.500000
# 25%       10060.75000    1.000000    29.500000      62.965000
# 50%       10120.50000    2.000000    89.990000     179.970000
# 75%       10180.25000    3.000000   249.990000     399.225000
# max       10240.00000   10.000000  3899.990000    3899.990000
